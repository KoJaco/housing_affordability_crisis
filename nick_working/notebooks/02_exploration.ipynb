# %% [markdown]
# # Lesson 02: Data Exploration
#
# In this lesson, you'll explore the filtered Sydney property data with visualizations and summary statistics.
#
# **Your Goal:**
# - Load the filtered Sydney data from `data/sydney/full.parquet`
# - Create visualizations: sales by year, price distribution, top suburbs by volume, average price over time
# - Calculate summary statistics (mean, median, min, max prices)
# - Explore geographic coverage (unique suburbs, postcodes, districts)
# - Understand data quality and completeness

# %%
# Import necessary libraries
# You'll need pandas, numpy, matplotlib, seaborn, and Path (look these up, read the docs pleaaasse)
# Set up plotting style (whitegrid) and figure size
# Suppress warnings

# %%
# Load filtered Sydney data from parquet file
# You can load either:
# - Option A: Combined file (data/sydney/full.parquet) if you saved it
# - Option B: Both separate files (full_houses.parquet and full_units.parquet) and combine them
# Hints:
# - Load from data/sydney/full.parquet (or load both house/unit files and concat)
# - Check if file exists first
# - Try fastparquet engine, fall back to default if needed
# - Print: number of records, date range, DataFrame shape, number of columns
# - If loading separate files, you might want to add a property_type column before combining

# %%
# Create visualizations
# Create a figure with 2x2 subplots (use plt.subplot(2, 2, n))

# Plot 1: Records per year
# Hints:
# - Group by 'year' and count records
# - Use plt.bar() to create a bar chart
# - Add labels, title, grid
# - Optionally add value labels on bars

# Plot 2: Purchase price distribution
# Hints:
# - Filter out extreme outliers (e.g., 1st-99th percentile) for better visualization
# - Use plt.hist() to show distribution
# - Convert prices to millions for readability
# - Add labels, title, grid

# Plot 3: Top 15 suburbs by number of sales
# Hints:
# - Use value_counts() on property_locality
# - Take top 15 with .head(15)
# - Use plt.barh() for horizontal bar chart
# - Invert y-axis for descending order
# - Add labels, title, grid

# Plot 4: Average purchase price by year
# Hints:
# - Group by year and calculate mean purchase_price
# - Use plt.plot() with markers
# - Convert to millions for readability
# - Add labels, title, grid
# - Rotate x-axis labels if needed

# Use plt.tight_layout() and plt.show() at the end

# %%
# Print summary statistics
# Hints:
# - Total sales records
# - Date range (min and max settlement_date)
# - Purchase price statistics: mean, median, min, max
# - Geographic coverage: unique suburbs, postcodes, district codes
# - Format numbers nicely with commas and currency symbols
