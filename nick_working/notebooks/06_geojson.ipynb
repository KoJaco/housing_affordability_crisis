# %% [markdown]
# # Lesson 06: GeoJSON Processing (Optional)
#
# This lesson is optional and only needed if you want to create geographic visualizations for a frontend.
#
# **Your Goal:**
# - Load NSW administrative boundaries GeoJSON file
# - Filter to Sydney suburbs only
# - Normalize suburb names for consistent matching
# - Save filtered GeoJSON for frontend use
#
# **Note:** You'll need the GeoJSON file from `/final/backend/notebooks/data/nsw-administrative-boundaries-theme-suburb.geojson` and your Sydney suburbs list.
#
# **Note:** You would usually deliver a large file via CDN, but we can use mapshaper to create a smaller file for this project and store it in our public dir in our frontend.

# %%
# Import necessary libraries
# You'll need json and Path
# Optional: pandas for data manipulation

# %%
# Load Sydney suburbs list
# Hints:
# - Load from data/sydney_burbs.json (or use the list you created earlier)
# - Convert to uppercase set for matching
# - Print how many suburbs loaded
# - Display sample suburbs

# %%
# Load NSW GeoJSON file
# Hints:
# - Load from data/nsw-administrative-boundaries-theme-suburb.geojson
# - Print total number of features
# - Check GeoJSON structure (type, features array)
# - Inspect a sample feature to understand property names

# %%
# Inspect feature structure
# Hints:
# - Look at first feature's properties
# - Find which property contains suburb name (could be 'suburbname', 'suburb', 'SUBURB', etc.)
# - Print sample properties to understand structure
# - Note the property name format (case, naming convention)

# %%
# Filter features to Sydney suburbs only
# Hints:
# - Loop through all features
# - Extract suburb name from properties (try multiple possible keys)
# - Normalize suburb name (uppercase, strip whitespace)
# - Check if normalized name is in your Sydney suburbs set
# - Collect matching features in a list
# - Track found and not found suburbs
# - Print how many Sydney features were found

# %%
# Check for missing suburbs
# Hints:
# - Compare your Sydney suburbs set with found suburbs
# - Find which suburbs from your list weren't found in GeoJSON
# - Print missing suburbs (if any)
# - This helps identify naming mismatches

# %%
# Normalize suburb property names
# Hints:
# - Create a copy of each filtered feature
# - Extract suburb name from various possible property names
# - Add a normalized 'suburb' property (uppercase) to each feature
# - Keep original properties for reference
# - This ensures consistent suburb naming in the output

# %%
# Create and save filtered GeoJSON
# Hints:
# - Create new GeoJSON structure: {"type": "FeatureCollection", "features": [...]}
# - Use normalized features list
# - Save to data/sydney_suburbs.geojson
# - Use json.dump() with indent for readability (or compact for smaller file)
# - Print confirmation and total features saved
# - Display sample normalized feature properties
