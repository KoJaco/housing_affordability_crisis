# %% [markdown]
# # Lesson 05: Test Database
#
# In this lesson, you'll write queries to verify your database and test various operations.
#
# **Your Goal:**
# - Connect to SQLite database
# - Write queries to verify data integrity
# - Count records in each table
# - Query specific suburbs or quarters
# - Test joins between tables
# - Verify constraints and indexes work

# %%
# Import necessary libraries
# You'll need sqlite3 and pandas
# Optional: matplotlib/seaborn for visualizations

# %%
# Connect to database
# Hints:
# - Connect to src/db/database.sqlite
# - Create a cursor
# - Print connection confirmation

# %%
# Verify tables exist
# Hints:
# - Query sqlite_master for table names
# - SELECT name FROM sqlite_master WHERE type='table'
# - Print list of tables
# - Should see: properties, suburb_quarterly, suburb_analytics

# %%
# Count records in each table
# Hints:
# - Use SELECT COUNT(*) FROM table_name for each table
# - Print counts for properties, suburb_quarterly
# - Compare to expected counts from your data
# - Optionally use pandas read_sql_query() for easier display

# %%
# Query specific suburb
# Hints:
# - SELECT * FROM properties WHERE suburb = 'MOSMAN' LIMIT 10
# - Try different suburbs
# - Count properties per suburb: SELECT suburb, COUNT(*) FROM properties GROUP BY suburb ORDER BY COUNT(*) DESC LIMIT 10
# - Use pandas read_sql_query() for better display

# %%
# Query quarterly data for a specific suburb
# Hints:
# - SELECT * FROM suburb_quarterly WHERE suburb = 'MOSMAN' ORDER BY year, quarter
# - Get latest quarter data: WHERE suburb = 'MOSMAN' ORDER BY year DESC, quarter DESC LIMIT 1
# - Calculate average median price per year for a suburb
# - Use pandas for easier manipulation

# %%
# Test joins between tables
# Hints:
# - Join properties and suburb_quarterly on suburb
# - Example: SELECT p.*, sq.median_price FROM properties p JOIN suburb_quarterly sq ON p.suburb = sq.suburb WHERE p.suburb = 'MOSMAN' LIMIT 10
# - Count properties per suburb/quarter combination
# - Use pandas read_sql_query() for easier joins

# %%
# Test constraints
# Hints:
# - Try inserting invalid property_type (should fail CHECK constraint)
# - Try inserting duplicate suburb/property_type/year/quarter (should fail UNIQUE constraint)
# - Verify indexes exist: SELECT name FROM sqlite_master WHERE type='index'
# - Test query performance with WHERE clauses on indexed columns

# %%
# Advanced queries (optional)
# Hints:
# - Find suburbs with highest median price in most recent quarter
# - Find suburbs with most sales in a specific year
# - Calculate price growth between quarters
# - Find suburbs with fastest settlements (lowest contract_to_settlement_days)
# - Create visualizations from query results
